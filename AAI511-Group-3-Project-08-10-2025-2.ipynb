# %% [markdown]
# # Music Composer Identification using Deep Learning
#
# The primary objective of this project is to develop a deep learning model that can predict the composer of a given musical score accurately. The project aims to accomplish this objective by using two deep learning techniques: Long Short-Term Memory (LSTM) and Convolutional Neural Network (CNN).
#
# ## Project Team & Responsibilities:
#
# * **Dom:** Data Collection, Data Preprocessing (MIDI conversion, segmentation, augmentation), Feature Extraction (Piano Rolls for CNN, Sequential Features for LSTM).
# * **Santosh:** CNN Model Building, Training, Evaluation, Optimization.
# * **Jim:** LSTM Model Building, Training, Evaluation, Optimization.
#
# ## Project Roadmap & Status:
#
# Here's a breakdown of our project phases and current status:
#
# 1.  **Initial Setup & Data Download (COMPLETED by Jim):**
#     * Basic imports are set up.
#     * The `blanderbuss/midi-classic-music` dataset has been downloaded from Kaggle.
#     * *Status:* Ready for data processing.
#
# 2.  **Data Preprocessing & Feature Extraction (COMPLETED by Dom):**
#     * **Goal:** Convert raw MIDI files into numerical features (Piano Rolls for CNNs, Sequential Features for LSTMs) and augment dataset.
#     * **Responsible:** Dom.
#     * *Current Status:* Completed / Needs implementation of the sections below.
#
# 3.  **Model Building (NEXT STEP for Team):**
#     * **Goal:** Design CNN and LSTM model architectures.
#     * **Responsible:** Santosh (CNN), Jim (LSTM).
#     * *Dependencies:* Requires processed data from Phase 2.
#
# 4.  **Model Training & Evaluation (AFTER Model Building):**
#     * **Goal:** Train the models and evaluate their performance using metrics like accuracy, precision, and recall.
#     * **Responsible:** Santosh (CNN), Jim (LSTM).
#     * *Dependencies:* Requires built models from Phase 3.
#
# 5.  **Model Optimization (Post Training):**
#     * **Goal:** Fine-tune model hyperparameters to improve performance.
#     * **Responsible:** Santosh (CNN), Jim (LSTM) & Dom (Feature Engineering).
#     * *Dependencies:* Requires initial model training.

# %%
# Imports
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, TensorDataset, random_split
import pandas as pd
import pickle
import collections
import random
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Data Collection
# The dataset contains the midi files of compositions from well-known classical composers like Bach, Beethoven, Chopin, and Mozart. The dataset has been labeled with the name of the composer for each score. Predictions are performed for only the below composers:
#
# 1-Bach
#
# 2-Beethoven
#
# 3-Chopin
#
# 4-Mozart

# %%
#%pip install kagglehub

import kagglehub

# Download latest version
path = kagglehub.dataset_download("blanderbuss/midi-classic-music")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/midi-classic-music

# %%
# List all files in the dataset path
for root, dirs, files in os.walk(path):
    for file in files:
        #print(os.path.join(root, file))
        # Check if the file is a MIDI file and contains 'bach' in its name.
        # There are other composers that need to be processed too.
        if (file.endswith('.mid') or file.endswith('.midi')) and 'bach' in file.lower():
            print(f"Found MIDI file: {file}")
            # Add file to Bach dataset processing logic here
# Out:
# Found MIDI file: Liszt Bach Prelude Transcription.mid
# Found MIDI file: C.P.E.Bach Solfeggieto.mid
# Found MIDI file: Piano version of Bachs two part inventions No.15.mid
# Found MIDI file: Piano version of Bachs two part inventions No.6.mid
# Found MIDI file: Piano version of Bachs two part inventions No.7.mid
# Found MIDI file: Piano version of Bachs two part inventions No.4.mid
# Found MIDI file: Piano version of Bachs two part inventions No...mid
# Found MIDI file: Piano version of Bachs two part inventions No.1.mid
# Found MIDI file: Piano version of Bachs two part inventions No.9.mid
# Found MIDI file: Piano version of Bachs two part inventions No.14.mid
# Found MIDI file: Piano version of Bachs two part inventions No.10.mid
# Found MIDI file: Piano version of Bachs two part inventions No.13.mid
# Found MIDI file: Piano version of Bachs two part inventions No.12.mid
# Found MIDI file: Piano version of Bachs two part inventions No.11.mid
# Found MIDI file: Piano version of Bachs two part inventions No.5.mid
# Found MIDI file: Piano version of Bachs two part inventions No.8.mid
# Found MIDI file: Piano version of Bachs two part inventions No.3.mid
# Found MIDI file: Piano version of Bachs two part inventions No.2.mid
# Found MIDI file: bachlein.mid
# Found MIDI file: bach_4.mid
# Found MIDI file: bach_1.mid
# Found MIDI file: bach_4p.mid
# Found MIDI file: bach2.mid
# Found MIDI file: bach.mid
# Found MIDI file: bach197c.mid
# Found MIDI file: bach_10p.mid
# Found MIDI file: bachaire.mid
# Found MIDI file: bachpfam.mid
# Found MIDI file: bachmen7.mid
# Found MIDI file: bach_13p.mid
# Found MIDI file: bach12a.mid
# Found MIDI file: bachmen6.mid
# Found MIDI file: bach0.mid
# Found MIDI file: bach_14.mid
# Found MIDI file: bachinv.mid
# Found MIDI file: bachg.mid
# Found MIDI file: bachto.mid
# Found MIDI file: bachpart.mid
# Found MIDI file: Six variations on Bach No.1.mid
# Found MIDI file: Six variations on Bach No.3.mid
# Found MIDI file: Fantasia Nach J. S. Bach.mid

# %% [markdown]
# Convert MIDI file to something useful for LSTM and CNN.

# %%
# I will place these here so they run after Kaggle download, as I encountered conflicts with the initial setup when adding above.
# !pip install music21
# !pip install pretty_midi
#!pip install --upgrade numpy # Ensure I have a recent numpy version
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.11/dist-packages (9.3.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from music21) (1.5.1)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.11/dist-packages (from music21) (4.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from music21) (3.10.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from music21) (10.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from music21) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from music21) (2.32.3)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.11/dist-packages (from music21) (24.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->music21) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->music21) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->music21) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->music21) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->music21) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->music21) (1.17.0)
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (2.0.2)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido>=1.1.16->pretty_midi) (25.0)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 4.4 MB/s eta 0:00:00
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592286 sha256=1f7931601d2b1ef581e195b1e4b8a8bb9de500e0485589d1c75e06b06e1035c8
#   Stored in directory: /root/.cache/pip/wheels/e6/95/ac/15ceaeb2823b04d8e638fd1495357adb8d26c00ccac9d7782e
# Successfully built pretty_midi
# Installing collected packages: mido, pretty_midi
# Successfully installed mido-1.3.3 pretty_midi-0.2.10

# %%
import music21
import pretty_midi
# Ensure numpy is up-to-date
import numpy as np  # Already imported, but good to have here for clarity

# %% [markdown]
# Data Pre-processing: Convert the musical scores into a format suitable for deep learning models. This involves converting the musical scores into MIDI files and applying data augmentation techniques.

# %%
# Data Preprocessing and Feature Extraction
HOME_DIR = Path.home()
KAGGLE_DOWNLOAD_PATH = HOME_DIR / ".cache" / "kagglehub" / "datasets" / "blanderbuss" / "midi-classic-music" / "versions" / "1"
MIDI_DIR = str(KAGGLE_DOWNLOAD_PATH)

OUTPUT_DIR = "./content/processed_data/"
SEGMENT_DURATION_SECONDS = 5
SAMPLES_PER_SECOND = 100

PITCH_LOW = 21
PITCH_HIGH = 108
NUM_PITCHES = PITCH_HIGH - PITCH_LOW + 1

AUGMENT_TRANSPOSITION_STEPS = [-3, -2, -1, 1, 2, 3]
AUGMENT_TEMPO_SCALES = [0.9, 1.1]

# Defines composers
COMPOSERS = ["Bach", "Beethoven", "Chopin", "Mozart"]

# Creates output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"MIDI data will be processed from: {MIDI_DIR}")
print(f"Processed data will be saved to: {OUTPUT_DIR}")

#DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

seed = 42  # Set a seed for reproducibility
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    print("Using CUDA GPU")
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False
# Out:
# MIDI data will be processed from: /root/.cache/kagglehub/datasets/blanderbuss/midi-classic-music/versions/1
# Processed data will be saved to: ./content/processed_data/
# Using CUDA GPU

# %% [markdown]
# ###Feature Extraction : Extracts features from the MIDI files, such as notes, chords, and tempo, using music analysis tools.
#
# Here, the preprocessed MIDI segments are converted into numerical representations. I've generated different formats for the CNN and LSTM models to leverage the strengths of each.
#
# * **For CNNs: The Piano Roll**
#     * **Purpose:** CNNs excel at recognizing visual patterns. A piano roll converts music into a 2D image (pitch vs. time), allowing the CNN to "see" and learn characteristic melodic shapes, harmonic voicings, and rhythmic patterns that define a composer's style.
#     * **Details:** The piano roll captures note activity (velocity) across a defined pitch range (MIDI 21-108) over time, sampled at 100 samples per second. All outputs are normalized to [0,1] and padded/truncated to a consistent shape.
# * **For LSTMs: Sequential Features (Chroma & Note Density)**
#     * **Purpose:** LSTMs are great tools for understanding temporal sequences. These features describe the harmonic content and musical activity at each point in time, allowing the LSTM to learn how a composer's musical ideas evolve.
#     * **Details:** Each time step in the sequence contains a 12-element Pitch Class Profile (Chroma) representing harmonic presence (e.g., C, C#, D) and a single value for overall note density/volume. These are also sampled at 100 samples per second and normalized.

# %%
# Feature Extraction - midi_to_sequential_features (for LSTMs)
# This function extracts time-series features like Pitch Class Profiles and note density from a MIDI segment for LSTMs

def midi_to_sequential_features(midi_data_segment: pretty_midi.PrettyMIDI, duration: float,
                                samples_per_second: int, pitch_low: int, pitch_high: int) -> np.ndarray:
    if not midi_data_segment.instruments:
        return None

    num_target_time_steps = int(duration * samples_per_second)
    num_features_per_timestep = 12 + 1 # Chroma + Note Density
    sequential_features = np.zeros((num_target_time_steps, num_features_per_timestep), dtype=np.float32)

    chroma_features = midi_data_segment.get_chroma(fs=samples_per_second).T
    print("Original chroma shape:", chroma_features.shape)  # should be (12, T)
    if chroma_features.shape[0] < num_target_time_steps:
        padding_needed = num_target_time_steps - chroma_features.shape[0]
        chroma_features = np.pad(chroma_features, ((0, padding_needed), (0, 0)), mode='constant')
    elif chroma_features.shape[0] > num_target_time_steps:
        chroma_features = chroma_features[:num_target_time_steps, :]

    note_density = np.zeros(num_target_time_steps, dtype=np.float32)
    for instrument in midi_data_segment.instruments:
        for note in instrument.notes:
            start_idx = int(note.start * samples_per_second)
            end_idx = int(note.end * samples_per_second)
            start_idx = max(0, min(start_idx, num_target_time_steps - 1))
            end_idx = max(0, min(end_idx, num_target_time_steps - 1))
            if end_idx >= start_idx:
                note_density[start_idx:end_idx] += note.velocity

    max_density = np.max(note_density)
    if max_density > 0:
        note_density /= max_density

    sequential_features[:, :12] = chroma_features
    sequential_features[:, 12] = note_density

    return sequential_features

# %%
from typing import Optional

# Feature Extraction - midi_to_piano_roll (for CNNs)
# This function converts a MIDI segment into a 2D image-like "piano roll" for CNNs.
def is_piano(instrument: pretty_midi.Instrument) -> bool:
    # Check program number (0-7 are all piano-related in General MIDI)
    return not instrument.is_drum and 0 <= instrument.program <= 7

def midi_to_piano_roll(midi_data_segment: pretty_midi.PrettyMIDI, duration: float,
                        samples_per_second: int, pitch_low: int, pitch_high: int) -> Optional[np.ndarray]:
    if not midi_data_segment.instruments:
        return None
    piano = None # Default instrument of acoustic piano, will be updated if a piano instrument is found
    for instrument in midi_data_segment.instruments:
        if is_piano(instrument):
            piano = instrument
    if (piano is None):
        print("No piano instrument found in MIDI segment.")
        return None

    # Fix: Use 'times' parameter and slice the piano roll to get the desired pitch range
    piano_roll = piano.get_piano_roll(fs=samples_per_second)

    # Slice to get the desired pitch range (pitch_low to pitch_high)
    piano_roll = piano_roll[pitch_low:pitch_high+1, :]
    piano_roll = piano_roll / 127.0

    num_target_time_steps = int(duration * samples_per_second)
    num_pitches = pitch_high - pitch_low + 1  # Should be 88
    current_time_steps = piano_roll.shape[1]

    if current_time_steps < num_target_time_steps:
        padding = np.zeros((num_pitches, num_target_time_steps - current_time_steps), dtype=np.float32)
        piano_roll = np.hstack([piano_roll, padding])
    elif current_time_steps > num_target_time_steps:
        piano_roll = piano_roll[:, :num_target_time_steps]

    return piano_roll.reshape(num_pitches, num_target_time_steps, 1)

# %%
# Utility Function - create_pretty_midi_segment
# This function extracts a specific time segment from a larger MIDI file.

def create_pretty_midi_segment(full_midi_data: pretty_midi.PrettyMIDI, start_time: float, end_time: float) -> pretty_midi.PrettyMIDI:
    segment_pm = pretty_midi.PrettyMIDI()
    for instrument in full_midi_data.instruments:
        new_instrument = pretty_midi.Instrument(program=instrument.program, is_drum=instrument.is_drum, name=instrument.name)
        for note in instrument.notes:
            if note.end > start_time and note.start < end_time:
                new_note = pretty_midi.Note(
                    velocity=note.velocity,
                    pitch=note.pitch,
                    start=max(0.0, note.start - start_time),
                    end=min(end_time - start_time, note.end - start_time)
                )
                if new_note.end > new_note.start:
                    new_instrument.notes.append(new_note)
        if new_instrument.notes:
            segment_pm.instruments.append(new_instrument)
    return segment_pm

# %%
# Utility Function - apply_augmentation
# This function modifies a MIDI segment by transposing its pitch or scaling its tempo.

def apply_augmentation(midi_data_segment: pretty_midi.PrettyMIDI, augmentation_type: str, value) -> pretty_midi.PrettyMIDI:
    augmented_midi = pretty_midi.PrettyMIDI()
    for instrument in midi_data_segment.instruments:
        new_instrument = pretty_midi.Instrument(program=instrument.program, is_drum=instrument.is_drum, name=instrument.name)
        for note in instrument.notes:
            new_note = pretty_midi.Note(note.velocity, note.pitch, note.start, note.end)
            new_instrument.notes.append(new_note)
        augmented_midi.instruments.append(new_instrument)

    if augmentation_type == 'transpose':
        for instrument in augmented_midi.instruments:
            for note in instrument.notes:
                note.pitch = int(max(0, min(127, note.pitch + value)))
    elif augmentation_type == 'tempo_scale':
        scale_value = float(value)
        for instrument in augmented_midi.instruments:
            for note in instrument.notes:
                note.start *= scale_value
                note.end *= scale_value
    else:
        raise ValueError(f"Unknown augmentation type: {augmentation_type}")
    return augmented_midi

# %%
def extract_segments_from_midi(midi_path, segment_duration=5.0, samples_per_second=100):
    try:
        full_midi = pretty_midi.PrettyMIDI(midi_path)
    except Exception as e:
        print(f"Error loading {midi_path}: {e}")
        return []

    total_duration = full_midi.get_end_time()
    segments = []

    for start_time in np.arange(0, total_duration, segment_duration):
        end_time = min(start_time + segment_duration, total_duration)

        segment = pretty_midi.PrettyMIDI()
        for instrument in full_midi.instruments:
            new_instrument = pretty_midi.Instrument(program=instrument.program, is_drum=instrument.is_drum)
            for note in instrument.notes:
                if start_time <= note.start < end_time:
                    new_note = pretty_midi.Note(
                        velocity=note.velocity,
                        pitch=note.pitch,
                        start=note.start - start_time,
                        end=min(note.end, end_time) - start_time
                    )
                    new_instrument.notes.append(new_note)
            if new_instrument.notes:
                segment.instruments.append(new_instrument)

        # Only append segments with valid instruments
        if segment.instruments:
            segments.append(segment)

    return segments

# %% [markdown]
# ### Data Processing Loop & Output Conclusion
#
# This section orchestrates the loading of MIDI files, segmenting them, applying all augmentations, extracting features, and finally saving the processed data.
#
# * **Process:** Iterates through each composer's MIDI files, segments them, applies both transposition and tempo scaling for each segment, and then generates both CNN and LSTM features.
# * **Output Data:** The processed features and corresponding labels are saved as `.pkl` files in the `/content/processed_data/` directory.
#
# ---
#
# #### **The data is ready for model training!**
#
# * **For CNN Model (Santosh):**
#     * Load `features_cnn.pkl`.
#     * Expected input shape: `(num_segments, 88, 500, 1)` - (total samples, pitches, time steps, channels).
# * **For LSTM Model (Jim):**
#     * Load `features_lstm.pkl`.
#     * Expected input shape: `(num_segments, 500, 13)` - (total samples, time steps, features per time step).
# * **Labels:**
#     * Load `labels.pkl` (numerical labels corresponding to composers).
#     * Load `composer_to_label.pkl` and `label_to_composer.pkl` to map between numerical labels and composer names.
#
# You can/should convert these NumPy arrays to PyTorch tensors for your models (e.g., `torch.tensor(data, dtype=torch.float32)` for features, `torch.tensor(labels, dtype=torch.long)` for labels).

# %%
# Define label mappings
composer_to_label = {composer: i for i, composer in enumerate(COMPOSERS)}
label_to_composer = {i: composer for composer, i in composer_to_label.items()}

# Define lists to hold features and labels
# These will be used to store the extracted features and corresponding labels for each composer.
# They will be converted to NumPy arrays later for model training.
features_cnn = []
features_lstm = []
labels = []

# Iterate through each composer
for composer in COMPOSERS:
    composer_dir = os.path.join(MIDI_DIR)
    print(f"Processing composer: {composer}")

    for root, dirs, files in os.walk(path):
        for file in files:
            print(os.path.join(root, file))
            # Check if the file is a MIDI file and contains 'bach' in its name.
            # There are other composers that need to be processed too.
            if (file.endswith('.mid') or file.endswith('.midi')) and composer.lower() in file.lower():
                midi_path = os.path.join(root, file)
                print("Reading file: ", file)

                try:
                    segments = extract_segments_from_midi(midi_path, SEGMENT_DURATION_SECONDS, SAMPLES_PER_SECOND)
                except Exception as e:
                    print(f"Skipping {file}: {e}")
                    continue

                for segment in segments:
                    all_augmented = [segment]

                    for step in AUGMENT_TRANSPOSITION_STEPS:
                        all_augmented.append(apply_augmentation(segment, 'transpose', step))
                    for scale in AUGMENT_TEMPO_SCALES:
                        all_augmented.append(apply_augmentation(segment, 'tempo_scale', scale))

                    for augmented_segment in all_augmented:
                        # CNN Features
                        piano_roll = midi_to_piano_roll(augmented_segment, duration=SEGMENT_DURATION_SECONDS,
                                                        samples_per_second=SAMPLES_PER_SECOND,
                                                        pitch_low=PITCH_LOW, pitch_high=PITCH_HIGH)
                        # LSTM Features
                        sequential = midi_to_sequential_features(augmented_segment, duration=SEGMENT_DURATION_SECONDS,
                                                                 samples_per_second=SAMPLES_PER_SECOND,
                                                                 pitch_low=PITCH_LOW, pitch_high=PITCH_HIGH)

                        # Append label only if both features were generated
                        if piano_roll is not None and sequential is not None:
                            features_cnn.append(piano_roll)
                            features_lstm.append(sequential)
                            labels.append(composer_to_label[composer])

print("Finished processing all composers.")

# Convert to NumPy arrays
np_features_cnn = np.array(features_cnn, dtype=np.float32)
np_features_lstm = np.array(features_lstm, dtype=np.float32)
labels = np.array(labels, dtype=np.int64)

# Save to disk
with open(os.path.join(OUTPUT_DIR, 'features_cnn.pkl'), 'wb') as f:
    pickle.dump(np_features_cnn, f)

with open(os.path.join(OUTPUT_DIR, 'features_lstm.pkl'), 'wb') as f:
    pickle.dump(np_features_lstm, f)

with open(os.path.join(OUTPUT_DIR, 'labels.pkl'), 'wb') as f:
    pickle.dump(labels, f)

with open(os.path.join(OUTPUT_DIR, 'composer_to_label.pkl'), 'wb') as f:
    pickle.dump(composer_to_label, f)

with open(os.path.join(OUTPUT_DIR, 'label_to_composer.pkl'), 'wb') as f:
    pickle.dump(label_to_composer, f)
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments Musicaux, Opus 94 Mov.1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in C minor No.1, D958 - Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments musicaux op94 D780 n6.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Impromptus op90 D899 n3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/13 Variations on a Theme by Anselm Hu"ttenbrenner D576 2var.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Symphony D589 n6 2mov ''Little C Major Symphony''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in C minor No.2, D958 - Adagio.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Symphony D485 n5 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments musicaux op94 D780 n2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Erlko"nig D328 op1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Klavierstucke D946 n1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Impromptus op142 D935 n2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments musicaux op94 D780 n3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Symphony D417 n4 3mov ''Tragic''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Ave Maria.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in B flat No.2, D960.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Strings Cuartet D353 n11 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Sylvia.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Symphony D417 n4 2mov ''Tragic''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Impromptus op142 D935 n3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Schwanengesang, D957 n9 ''Ihr Bild''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Valses Sentimentales op50 D779.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments Musicaux, Opus 94 Mov.4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Lieder D774 Auf Dem Wasser Zu Singer.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in B flat No.1, D960 -Scherzo- Allegro vivace con.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Moments Musicaux, Opus 94 Mov.2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Klavierstucke D946 n2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Fantasie D760 3mov ''Wanderer''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Symphony D944 n9 2mov ''Great''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Die scho"ne Mu"llerin D795 op25 n1 Das Wandern.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Schwanengesang D957 11mov ''Die Stadt''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Schwanengesang D957 14 ''Die Taubenpost''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Schwanengesang D957 02mov ''Kriegers Ahnung''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Winterreise 24 Der leierman.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in B flat No.1, D960 -Molto moderato.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Strings Cuartet D353 n11 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonata in A No3, D959.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n17 D850 op53 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n14 D784 op143 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n09 D575 op147 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n21 D960 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n16 D845 op42 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n09 D575 op147 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n09 D575 op147 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n17 D850 op53 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n16 D845 op42 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n17 D850 op53 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n04 D537 op164 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n21 D960 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n21 D960 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n21 D960 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n20 D959 2mov.MID
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n19 D958 3mov.MID
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n16 D845 op42 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata D568 op.posth.122.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n09 D575 op147 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n14 D784 op143 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n16 D845 op42 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n04 D537 op164 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n17 D850 op53 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n14 D784 op143 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata D537 op.posth164 n4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schubert/Piano Sonatas/Piano Sonata n04 D537 op164 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Komzak/Neues Leben, opus 210.mid
# /kaggle/input/midi-classic-music/midiclassics/Czibulka/Stephanie Gavotte.mid
# /kaggle/input/midi-classic-music/midiclassics/Straus/The Mirror Song.mid
# /kaggle/input/midi-classic-music/midiclassics/Straus/The Chocolate Soldier Selection.mid
# /kaggle/input/midi-classic-music/midiclassics/Durand, MA/Premie`re Valse, opus 83.mid
# /kaggle/input/midi-classic-music/midiclassics/MacBeth/Seranata (Love in Idleness).mid
# /kaggle/input/midi-classic-music/midiclassics/Paderewski/Menuet a` l'antique, Opus.14, No.1.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Medley from An American in Paris.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/It Ain't Necessarily So.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Someone To Watch Over Me.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Prelude 1 Allegro ben ritmato e deciso.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Piano Concerto in F, 1st movement.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Porgy and Bess.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/American in Paris.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Swanee.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Prelude 2 Andante con moto e poco rubato.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Prelude 3 Allegro ben ritmato e deciso.mid
# /kaggle/input/midi-classic-music/midiclassics/Gershwin/Lullaby.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 07mov Domine Gili Unigenite.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 06mov Domine Deus.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op8 n5 RV253 ''La Tempesta di Mare''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Flute and String Concerto n12 ''La Tempesta di Mare''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe Concerto op11 n6 RV460.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n2 RV315 ''Summer'' 1mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op8 n6 ''Ill Piacere''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto for violin and cello RV546 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe Concerto op11 n6 1mov RV461.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n3 RV293 ''Autumm'' 3mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n4 RV297 ''Winter'' 1mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto n11 ''Cimento de la armonia e de la invenzione''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Chamber Concerto for flute violin bassoon and continuo RV106 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 02mov Et In Terra Pax.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n4 RV297 ''Winter'' 3mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe and Bassoon Concerto RV545 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 09mov Qui Tollis.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n4 RV297 ''Winter'' 2mov Largo.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op9 n6 RV348 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 04mov Gratias Agimus.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe and Bassoon Concerto RV545 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Lute Concerto 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto RV363 1mov ''Il cornetto da posta''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Strings Concerto RV158.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n3 RV293  ''Autumm'' 2mov Largo.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto n100.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op9 n8 RV238.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Lute Concerto 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n3 RV293 ''Autumm'' 1mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n1 RV269  ''Spring'' 2mov Adagio.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe Concerto op11 n6 3mov RV461.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto Viola d'Amore and Lute RV540.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Two Flutes Concerto RV533 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Lute Concerto 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto for violin and cello RV546 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op9 n6 RV348 1-2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 01mov Gloria In Exelsis.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op8 n07 RV242 ''Per Pisendel''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Two Oboes Concerto RV535 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 05mov Propter magnam Gloriam.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n1 RV269 ''Spring'' 3mov Danza Pastorale.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 03mov Laudamus Te.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe Concerto op11 n6 2mov RV461.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 08mov Domine Deus Agnus Dei.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op9 n7 RV359 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op9 n2 RV345.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op8 n12 RV178 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Oboe and Bassoon Concerto RV545 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Violin Concerto op8 n10 RV362 ''La Caccia''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 12mov Qum Sancto Espiritu.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 11mov Quoniam.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n1 RV269 ''Spring'' 1mov Allegro.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Gloria RV589 10mov Qui Sedes.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n2 RV315 ''Summer'' 2mov Adagio.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/The Four Seasons op8 n2 RV315 ''Summer'' 3mov Presto.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Chamber Concerto for flute violin bassoon and continuo RV106 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concerto for violin and cello RV546 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Magnificat n8 ''Sicut Locutus''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n02 for Violin Strings and Continuo RV279 1mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n01 for Violin Strings and Continuo RV383 2mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n02 for Violin Strings and Continuo RV279 2mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n03 for Violin Strings and Continuo RV301 2mov  ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n01 for Violin Strings and Continuo RV383 3mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n02 for Violin Strings and Continuo RV279 3mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n03 for Violin Strings and Continuo RV301 1mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n03 for Violin Strings and Continuo RV301 3mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n04 for Violin Strings and Continuo RV357 3mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n01 for Violin Strings and Continuo RV383 1mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n04 for Violin Strings and Continuo RV357 2mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op4 01-04  ''La Stravaganza''/Concerto op4 n04 for Violin Strings and Continuo RV357 1mov ''La Stravaganza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n11 for 2 Violins RV565 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n02 for 2 Violins and Cello RV578 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n03 for Violin RV310 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n02 for 2 Violins and Cello RV578 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n09 for RV230 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n04 for 4 Violins RV550 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n12 for Violin RV265 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n08 for 2 Violins RV522 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n02 for 2 Violins and Cello RV578 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n08 for 2 Violins RV522 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n09 for Violin RV230 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n09 for Violin RV230 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n07 for 4 Violins RV567 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n05 for 2 Violins RV519 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n01 for 4 Violins RV549 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n12 for Violin RV265 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n11 for 2 Violins RV565 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n06 for Violin RV356 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n01 for 4 Violins RV549 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n07 for 4 Violins RV567 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n11 for 2 Violins RV565 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n04 for 4 Violins RV550 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n03 for Violin RV310 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n12 for Violin RV265 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n11 for 2 Violins RV565 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n06 for Violin RV356 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n08 for 2 Violins RV522 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n06 for Violin RV356 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n10 for 4 Violins and Cello RV580 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n01 for 4 Violins RV549 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n10 for 4 Violins and Cello RV580 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n05 for 2 Violins RV519 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n07 for 4 Violins RV567 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n04 for 4 Violins RV550 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n10 for 4 Violins and Cello RV580 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n05 for 2 Violins RV519 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n03 for Violin RV310 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Mehul/Les Aveugles De Tolede (Die Beiden Blinden).mid
# /kaggle/input/midi-classic-music/midiclassics/Peterson-Berger/Lawn tennis.mid
# /kaggle/input/midi-classic-music/midiclassics/Peterson-Berger/Entry into the Summer Grove.mid
# /kaggle/input/midi-classic-music/midiclassics/Peterson-Berger/Summersong.mid
# /kaggle/input/midi-classic-music/midiclassics/Peterson-Berger/Gratulation.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n12.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Piano Concerto op54 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n5.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from Childhood Op. 15 No.2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Abegg Variations op1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n02.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n13.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Piano Sonata n2 op22 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n06.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n04.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/8 Novelettes op21 n4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/8 Novelettes op21 n2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Papillons op2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Waldszenen op82 n2 ''Jager Auf Der Lauer''.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n05.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n3 op97 ''Rhenish'' 5mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Piano Sonata n2 op22 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n03.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n18.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n05.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from Childhood Op. 15 No.5.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from Childhood Op. 15 No.3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Piano Sonata n2 op22 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Moment Musicau No.4 in C#- Op. 94 - D 780.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n06.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n10.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n3 op97 ''Rhenish'' 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n07.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Romance.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n3 op97 ''Rhenish'' 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/8 Novelettes op21 n1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n11.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n3 op97 ''Rhenish'' 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from Childhood Op. 15 No.4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n19.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Carnaval Op.9 No.1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Grillen in D flat, Fantaisiestuck opus.12, No.4.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n01.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n2.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n4 op120 4mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n09.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Etude op13 n3.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n14.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/8 Fantaisies Kreisleriana op16.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from Childhood Op. 15 No.6.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n2 op61 3mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n07.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Fantasiestu"cke op12 n1 Des Abends.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n4 op120 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Symphony n4 op120 2mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Concertstu"ck for Piano and Orchestra op92.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Moment Musicau No.5 in F-, Op. 94 - D 780.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Album fur die Jugend op68 n01.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Schuman Toccata op7.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n6.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Scenes from childhood op15 n08.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/6 Impromptus ''Bilder aus Osten'' for 4-hands op66 n1.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Piano Sonata n2 op22 1mov.mid
# /kaggle/input/midi-classic-music/midiclassics/Schumann/Fantasy in C op17.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.G.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.A.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/Symphony of Psalms, Mov.1.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.E.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.C
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.F.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.B.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/Symphony of Psalms, Mov.3.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/Russian dance from Petroushka.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.D.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/Symphony of Psalms, Mov.2.mid
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/The Rite of Spring, Mov.H
# /kaggle/input/midi-classic-music/midiclassics/Stravinski/Firebird done for Flute.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/The Battle of Prague (Fantasia).mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/A Picture of Her Face.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/A Breeze From Alabama.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/Combination Dance.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/Bethena a Concerto Waltz.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/Coca Club.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/The Entertainer.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/The Favorite.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/The Chrysanthemum - An Afro-American Intermezzo.mid
# /kaggle/input/midi-classic-music/midiclassics/Joplin/Cleopha March And Two-Step.mid
# /kaggle/input/midi-classic-music/midiclassics/Fucick/Entry of the Gladiators. (March of Triumph).mid
# /kaggle/input/midi-classic-music/midiclassics/Fucick/Children of the Regiment (Regimentskinder).mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.15.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.13.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.8.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.11.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.44.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.5.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.50.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.7.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.12.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.19.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.3.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.299 No.34.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.14.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.4.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.17.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.9.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Dancing the Jig.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.1.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.299 No.07.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.16.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.18.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.10.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Czerny ''Die Schule Der Gelaufigkeit'' op299 n21.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.2.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.6.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Etude Op.740 No.27.mid
# /kaggle/input/midi-classic-music/midiclassics/Czerny/Czerny op33 ''La Ricordanza''.mid
# /kaggle/input/midi-classic-music/midiclassics/Sibelius/The Aspen.mid
# /kaggle/input/midi-classic-music/midiclassics/Sibelius/The Spruce.mid
# /kaggle/input/midi-classic-music/midiclassics/Sibelius/The Solitary Fir Tree.mid
# /kaggle/input/midi-classic-music/midiclassics/Sibelius/When the Roan-tree Flowers.mid
# /kaggle/input/midi-classic-music/midiclassics/Sibelius/The Birch Tree.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/2001_2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/76tmbons.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/2ptinv1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5thsym.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/1812over.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5thsymph.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5th1stmv.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5th3rdmv.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5thsymp.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/76tubas.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/varios/5th2ndmv.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue23.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chinese.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gersh5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmklnach.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bachlein.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue14.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chord.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ff2theme.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/beeth5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms26.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/anitras.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bakson61.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bosendor.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bee9_2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/g2fug0.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/arenskiy.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f03c_maj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach_4.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms53.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue06.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/brass.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/d_tocca.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f11fmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/greenslv.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/aria.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/d4saiso2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cannon.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f05dmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ba_bran4.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/c1pre.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f10emin.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hallauia.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bluebell.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue12.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms22.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bsmetana.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/america.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/canontub.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bumblebe.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ballad1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ballad.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms21.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/concrto3.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/dx.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/haydngyp.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cosmos.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach_1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chopstik.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/canyon.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/br_hung5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f23bmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hain_gs.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms44.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/branden4.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/be_sym5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue19.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f04c_min.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gersh1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/adagio.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fifth.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/a_1pre.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/brand3.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/d4saison.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/anthem.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms54.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/b_fugaam.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/guitar.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/greensl3.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/allegr.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chopin7.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach_4p.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/finale.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/dance_1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/g_1pre.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugueam.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ch_fant4.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue22.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bumble_b.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/furelis.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f19amaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/for_unto.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/exodus.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/dance.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gymnoped.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/canon.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/handms37.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue13.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/asonatam.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cbwaltz.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fant3_10.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue05.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/greensl.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/clar1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/demo0012.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chopin66.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/allegro2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/deb_ara1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmklnac2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bakson62.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/elise.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cant.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/carol.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/avemaria.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/adestefi.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hum_t7_1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bluedanu.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cldlunez.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/arabesqu.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f24bmin.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/beet54s.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/12tone1.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/adeste.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bethovn5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/baserhap.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/canonind.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fantasia.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gavotteg.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/demo12.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hungrhap.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f12fmin.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f15gmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/brndnbrg.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f01cmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/flghtbee.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hungdan5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmjupit.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/art_deco.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ba_v2con.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach197c.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/candle.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/casica.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue17.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hayden.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue10.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/carolbel.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f20amin.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/beetljuc.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/almonds.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gersh3.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f06dmin.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cannon_d.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/chop64_2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmclair.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/autumn.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/b_14inv.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/auldls.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f13fmaj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bach_10p.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue11.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmfigaro.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/haydnand.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/clar2.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ba_bran6.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hrnpipe.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/demo4.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/albinoni.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/hoedow.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/bakson63.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/cosecose.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fuguedm.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue21.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ha_opera.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gminuet.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gloria.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/ch_fant5.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/gmmtnkng.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/fugue07.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f17a_maj.mid
# /kaggle/input/midi-classic-music/midiclassics/Varios - Ti'tulo desconocido/a_h/f08e_min.mid
# ...
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K445.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K307.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K547.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K288.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K009.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K461.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K336.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K539.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K192.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K507.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K478.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K509.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K546.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K535.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K226.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K413.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K327.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K457.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K497.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K267.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K486.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K474.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K480.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K471.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K197.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K240.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K438.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K298.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K401.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K551.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K460.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K037.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K235.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K121.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K304.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K189.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K271.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K236.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K278.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K453.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K130.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K047.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K435.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K157.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K503.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K160.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K014.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K520.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K312.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K166.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K439.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K357.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K185.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K169.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K463.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K485.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K363.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K548.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K067.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K261.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K256.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K530.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K113.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K262.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K073.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K370.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K427.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K433.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K495.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K425.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K411.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K081.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K458.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K167.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K064.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K285.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K484.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K092.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K296.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K178.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K115.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K220.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K429.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K060.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K200.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K456.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K023.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K412.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K140.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K515.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K045.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K112.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K243.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K323.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K079.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K041.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K404.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K314.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K181.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K061.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K415.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K293.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K054.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K177.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K145.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K208.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K003.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K036.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K184.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K545.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K002.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K541.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K201.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K165.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K038.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K173.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K246.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K300.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K525.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K053.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K153.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K459.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K097.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K221.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K265.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K247.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K385.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K127.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K114.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K353.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K063.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K321.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K058.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K139.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K068.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K042.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K407.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K283.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K324.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K209.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K418.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K248.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K249.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K022.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K465.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K034.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K219.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K084.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K387.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K250.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K168.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K102.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K346.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K316.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K332.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K109.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K263.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K015.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K475.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K383.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K233.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K294.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K234.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/sonatas/K252.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K543.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K514.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K519.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K538.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K511.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K549.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K534.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K554.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K518.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K552.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K516.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K502.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K506.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K537.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K513.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K512.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K522.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K526.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K553.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K532.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K521.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K500.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K528.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K523.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K510.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K540.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K531.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K501.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K550.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K536.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K524.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K508.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K529.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K527.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K544.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K504.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K555.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K542.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K517.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K505.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K533.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K547.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K539.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K507.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K509.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K546.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K535.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K551.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K503.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K520.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K548.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K530.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K515.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K545.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K541.MID
# /kaggle/input/midi-classic-music/midiclassics/Scarlatti/v5/K525.MID
# /kaggle/input/midi-classic-music/Ambroise/Polonaise (1905)..mid
# /kaggle/input/midi-classic-music/Ambroise/Dance Fantastique.mid
# Finished processing all composers.

# %%
# Print summary of saved data
print(f"Saved {len(np_features_cnn)} CNN features and {len(np_features_lstm)} LSTM features.")
print(f"Saved {len(labels)} labeled examples for training.")
# Out:
# Saved 10215 CNN features and 10215 LSTM features.
# Saved 10215 labeled examples for training.

# %% [markdown]
# CNN Input: (batch_size, 1, 88, 500) → channel-first PyTorch format (grayscale piano roll)
# CNN Output per segment: (batch_size, time_steps=some_N, features_per_step=some_M)

# %%
class ComposerCNN(nn.Module):
    def __init__(self, num_pitches, num_time_steps):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        # Use integer division and guard with adaptive pooling if needed
        pooled_pitches = max(1, num_pitches // 4)
        pooled_steps   = max(1, num_time_steps // 4)
        self.fc1 = nn.Linear(64 * pooled_pitches * pooled_steps, 128)
        self.fc2 = nn.Linear(128, len(COMPOSERS))

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, 2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)  # Flatten
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model_cnn = ComposerCNN(NUM_PITCHES, int(SEGMENT_DURATION_SECONDS * SAMPLES_PER_SECOND)).to(DEVICE)

# %% [markdown]
# Model Building: Develop a deep learning model using LSTM and CNN architectures to classify the musical scores according to the composer.

# %% [markdown]
# LSTM Input Shape: (batch_size, time_steps, features_per_step) → same as (batch_size, seq_len, input_size)

# %%
# Hyperparameters
input_size = 13         # 12 chroma + 1 note density
hidden_size = 128       # Can be tuned
num_layers = 2          # Can be tuned
num_classes = len(COMPOSERS)    # based on the number of composer labels
batch_size = 64
num_epochs = 30
learning_rate = 0.001

# %%
# ------------------------------
# Define the LSTM Model
# ------------------------------
class ComposerLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(ComposerLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True,
                            dropout=0.3,
                            bidirectional=False)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # x: (batch_size, seq_len, input_size)
        lstm_out, _ = self.lstm(x)  # output: (batch_size, seq_len, hidden_size)
        out = lstm_out[:, -1, :]    # Take last time step
        out = self.fc(out)
        return out

# Initialize model, loss, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lstm_model = ComposerLSTM(input_size, hidden_size, num_layers, num_classes).to(DEVICE)
criterion = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(lstm_model.parameters(), lr=learning_rate)

# %%
# ------------------------------
# Load Preprocessed Data
# ------------------------------
with open(os.path.join(OUTPUT_DIR, 'features_lstm.pkl'), 'rb') as f:
    X = pickle.load(f)
with open(os.path.join(OUTPUT_DIR, 'labels.pkl'), 'rb') as f:
    y = pickle.load(f)

# Convert to PyTorch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)        # Shape: (N, 500, 13)
y_tensor = torch.tensor(y, dtype=torch.long)           # Shape: (N,)

print(X_tensor.shape)  # Should be (N, 500, 13
print(y_tensor.shape)  # Should be (N,)

# Ensure the input tensor is 3D: (batch_size, seq_len, input_size)
if X_tensor.ndim == 2:
    X_tensor = X_tensor.unsqueeze(1)  # Add a dimension for seq_len if missing
elif X_tensor.ndim != 3:
    raise ValueError(f"Expected X_tensor to be 2D or 3D, got {X_tensor.ndim}D tensor instead.")

# Dataset and DataLoader
dataset = TensorDataset(X_tensor, y_tensor)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_ds, val_ds = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=batch_size, pin_memory=True, num_workers=2)
# Out:
# torch.Size([10215, 500, 13])
# torch.Size([10215])

# %%
train_losses = []
val_accuracies = []

# %% [markdown]
# Model Training: Train the deep learning model using the pre-processed and feature-extracted data.

# %%
# ------------------------------
# Training Loop
# ------------------------------
for epoch in range(num_epochs):
    lstm_model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(DEVICE), y_batch.to(DEVICE)

        optimizer.zero_grad()
        outputs = lstm_model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)

    # Validation
    lstm_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)
            outputs = lstm_model(X_val)
            _, predicted = torch.max(outputs.data, 1)
            total += y_val.size(0)
            correct += (predicted == y_val).sum().item()

    val_accuracy = 100 * correct / total
    train_losses.append(avg_train_loss)
    val_accuracies.append(val_accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}, Validation Accuracy: {val_accuracy:.2f}%")

# Save the model
torch.save(lstm_model.state_dict(), "composer_lstm_model.pth")
# Out:
# Epoch [1/30], Loss: 0.1731, Validation Accuracy: 91.24%
# Epoch [2/30], Loss: 0.1349, Validation Accuracy: 92.22%
# Epoch [3/30], Loss: 0.1756, Validation Accuracy: 91.43%
# Epoch [4/30], Loss: 0.1526, Validation Accuracy: 93.34%
# Epoch [5/30], Loss: 0.1295, Validation Accuracy: 93.54%
# Epoch [6/30], Loss: 0.1615, Validation Accuracy: 93.34%
# Epoch [7/30], Loss: 0.1163, Validation Accuracy: 93.29%
# Epoch [8/30], Loss: 0.1299, Validation Accuracy: 94.18%
# Epoch [9/30], Loss: 0.0947, Validation Accuracy: 94.62%
# Epoch [10/30], Loss: 0.0740, Validation Accuracy: 94.08%
# Epoch [11/30], Loss: 0.0944, Validation Accuracy: 94.03%
# Epoch [12/30], Loss: 0.0778, Validation Accuracy: 93.64%
# Epoch [13/30], Loss: 0.1051, Validation Accuracy: 92.85%
# Epoch [14/30], Loss: 0.0794, Validation Accuracy: 93.98%
# Epoch [15/30], Loss: 0.0747, Validation Accuracy: 94.47%
# Epoch [16/30], Loss: 0.0708, Validation Accuracy: 94.62%
# Epoch [17/30], Loss: 0.0658, Validation Accuracy: 95.11%
# Epoch [18/30], Loss: 0.1071, Validation Accuracy: 94.42%
# Epoch [19/30], Loss: 0.0876, Validation Accuracy: 94.03%
# Epoch [20/30], Loss: 0.0622, Validation Accuracy: 95.30%
# Epoch [21/30], Loss: 0.0483, Validation Accuracy: 95.69%
# Epoch [22/30], Loss: 0.0701, Validation Accuracy: 93.39%
# Epoch [23/30], Loss: 0.0600, Validation Accuracy: 95.55%
# Epoch [24/30], Loss: 0.0368, Validation Accuracy: 95.84%
# Epoch [25/30], Loss: 0.0355, Validation Accuracy: 95.45%
# Epoch [26/30], Loss: 0.0374, Validation Accuracy: 95.15%
# Epoch [27/30], Loss: 0.0572, Validation Accuracy: 95.55%
# Epoch [28/30], Loss: 0.0397, Validation Accuracy: 95.30%
# Epoch [29/30], Loss: 0.0327, Validation Accuracy: 95.64%
# Epoch [30/30], Loss: 0.0288, Validation Accuracy: 95.99%

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12,5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, marker='o', label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.grid(True, alpha=0.3)
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, val_accuracies, marker='o', color='orange', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy over Epochs')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# CNN Model training and evaluation

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

def evaluate_model(model, loader, device):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            preds = logits.argmax(1)
            y_true.extend(yb.cpu().numpy())
            y_pred .extend(preds.cpu().numpy())
    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='macro', zero_division=0)
    return acc, prec, rec, f1, confusion_matrix(y_true, y_pred)

# %%
with open(os.path.join(OUTPUT_DIR, 'features_cnn.pkl'), 'rb') as f:
    Xc = pickle.load(f)  # (N, P, T, 1)
Xc_tensor = torch.tensor(Xc, dtype=torch.float32).permute(0, 3, 1, 2)  # -> (N,1,P,T)
yc_tensor = torch.tensor(labels, dtype=torch.long)

ds_cnn = TensorDataset(Xc_tensor, yc_tensor)
train_size = int(0.8 * len(ds_cnn))
val_size   = len(ds_cnn) - train_size
train_cnn, val_cnn = random_split(ds_cnn, [train_size, val_size])

model_cnn = ComposerCNN(NUM_PITCHES, int(SEGMENT_DURATION_SECONDS * SAMPLES_PER_SECOND)).to(DEVICE)
opt_cnn = optim.Adam(model_cnn.parameters(), lr=1e-3)
crit = nn.CrossEntropyLoss().to(DEVICE)

for epoch in range(num_epochs):
    model_cnn.train()
    for xb, yb in DataLoader(train_cnn, batch_size=128, shuffle=True):
        xb, yb = xb.to(device), yb.to(device)
        opt_cnn.zero_grad()
        loss = crit(model_cnn(xb), yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model_cnn.parameters(), 1.0)
        opt_cnn.step()
    acc, prec, rec, f1, _ = evaluate_model(model_cnn, DataLoader(val_cnn, batch_size=128), DEVICE)
    print(f"[CNN] Epoch {epoch+1}: acc={acc:.3f} P={prec:.3f} R={rec:.3f} F1={f1:.3f}")
# Out:
# [CNN] Epoch 1: acc=0.905 P=0.898 R=0.790 F1=0.836
# [CNN] Epoch 2: acc=0.908 P=0.842 R=0.886 F1=0.862
# [CNN] Epoch 3: acc=0.936 P=0.911 R=0.910 F1=0.911
# [CNN] Epoch 4: acc=0.943 P=0.952 R=0.881 F1=0.912
# [CNN] Epoch 5: acc=0.978 P=0.966 R=0.977 F1=0.971
# [CNN] Epoch 6: acc=0.978 P=0.965 R=0.976 F1=0.970
# [CNN] Epoch 7: acc=0.971 P=0.947 R=0.984 F1=0.963
# [CNN] Epoch 8: acc=0.986 P=0.980 R=0.981 F1=0.980
# [CNN] Epoch 9: acc=0.988 P=0.985 R=0.979 F1=0.982
# [CNN] Epoch 10: acc=0.988 P=0.984 R=0.981 F1=0.983
# [CNN] Epoch 11: acc=0.990 P=0.985 R=0.987 F1=0.986
# [CNN] Epoch 12: acc=0.988 P=0.990 R=0.974 F1=0.982
# [CNN] Epoch 13: acc=0.988 P=0.985 R=0.980 F1=0.983
# [CNN] Epoch 14: acc=0.989 P=0.995 R=0.974 F1=0.984
# [CNN] Epoch 15: acc=0.990 P=0.988 R=0.983 F1=0.985

# %%
class CNNEncoder(nn.Module):
    def __init__(self, out_channels=64):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, out_channels, kernel_size=3, padding=1)
        # pool over pitch only: (2,1) halves pitch, keeps time
        self.pool_pitch = nn.MaxPool2d(kernel_size=(2,1))

    def forward(self, x):
        # x: (N, 1, P, T)
        x = torch.relu(self.conv1(x))
        x = self.pool_pitch(x)             # (N, 32, P/2, T)
        x = torch.relu(self.conv2(x))
        x = self.pool_pitch(x)             # (N, C, P/4, T)
        # global average over remaining pitch bins -> (N, C, 1, T)
        x = x.mean(dim=2, keepdim=True)
        x = x.squeeze(2)                   # (N, C, T)
        x = x.permute(0, 2, 1)             # (N, T, C)
        return x

# %%
class FusionLSTM(nn.Module):
    def __init__(self, seq_input_size, cnn_feat_size, hidden_size, num_layers, num_classes, dropout=0.3):
        super().__init__()
        self.lstm = nn.LSTM(input_size=seq_input_size + cnn_feat_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True,
                            dropout=dropout,
                            bidirectional=False)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, seq_feats, cnn_feats):
        # seq_feats: (N, T, 13), cnn_feats: (N, T, C)
        x = torch.cat([seq_feats, cnn_feats], dim=-1)  # (N, T, 13+C)
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        return self.fc(out)

# %%
import torch

# LSTM features
X_seq = torch.tensor(features_lstm, dtype=torch.float32)               # (N, T, 13)

# CNN piano-roll features -> (N,1,P,T)
X_roll = torch.tensor(features_cnn, dtype=torch.float32).permute(0,3,1,2)
y_t = torch.tensor(labels, dtype=torch.long)

# Create a TensorDataset for the combined features
dataset_full = TensorDataset(X_seq, X_roll, y_t)
# Out:
# /tmp/ipython-input-2099519306.py:4: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   X_seq = torch.tensor(features_lstm, dtype=torch.float32)               # (N, T, 13)

# %%
# Split the dataset into training and validation sets
train_size = int(0.8*len(dataset_full))
train_ds, val_ds = random_split(dataset_full, [train_size, len(dataset_full) - train_size])

# %%
# For testing, reduce the size of the training set
#frac = 0.2  # use 20% for quick tests

# Randomly select a subset of the training set
#y_t = y_t[train_ds.indices]  # Get the labels for the training set
#N = len(y_t)
#idx = torch.randperm(N)
#sub_idx = idx[:int(N * frac)]

#dataset_sub  = Subset(dataset_full, sub_idx)

# Split AFTER subsetting (keeps test quick too)
#sub_train_size = int(0.8 * len(dataset_sub))
#train_ds, val_ds = random_split(dataset_sub, [sub_train_size, len(dataset_sub) - sub_train_size])

# %%
train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, pin_memory=True, num_workers=2)
val_loader   = DataLoader(val_ds,   batch_size=64, pin_memory=True, num_workers=2)

# %%
cnn_enc = CNNEncoder(out_channels=64).to(DEVICE)
fusion_model   = FusionLSTM(seq_input_size=13, cnn_feat_size=64,
                     hidden_size=128, num_layers=2,
                     num_classes=len(COMPOSERS), dropout=0.3).to(DEVICE)

params = list(cnn_enc.parameters()) + list(fusion_model.parameters())
optimizer = optim.Adam(params, lr=1e-3)
criterion = nn.CrossEntropyLoss().to(DEVICE)

# %%
def compute_cls_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro', zero_division=0
    )
    return acc, prec, rec, f1

# %%
def evaluate_fusion(cnn_enc, fusion_model, loader, device):
    cnn_enc.eval(); fusion_model.eval()
    y_true, y_pred = [], []
    running_loss = 0.0
    with torch.no_grad():
        for seq_b, roll_b, yb in loader:
            seq_b, roll_b, yb = seq_b.to(device, non_blocking=True), roll_b.to(device, non_blocking=True), yb.to(device, non_blocking=True)
            cnn_feats = cnn_enc(roll_b)           # (N,T,C)
            logits = fusion_model(seq_b, cnn_feats)
            loss = criterion(logits, yb)
            running_loss += loss.item()
            y_true.extend(yb.cpu().numpy())
            y_pred.extend(logits.argmax(1).cpu().numpy())
    acc, prec, rec, f1 = compute_cls_metrics(y_true, y_pred)
    return running_loss / max(1, len(loader)), acc, prec, rec, f1

# %%
logger = {"epoch": [], "train_loss": [], "val_loss": [],
          "val_acc": [], "val_prec": [], "val_rec": [], "val_f1": []}

scaler = torch.amp.GradScaler(DEVICE.type)
num_epochs = 20

# Training loop for the fusion model
for epoch in range(num_epochs):
    cnn_enc.train()
    fusion_model.train()
    running = 0.0
    print(f"Epoch {epoch+1}/{num_epochs}")
    for seq_batch, roll_batch, y_batch in train_loader:
        seq_batch = seq_batch.to(DEVICE)          # (N,T,13)
        roll_batch = roll_batch.to(DEVICE)        # (N,1,P,T)
        y_batch = y_batch.to(DEVICE)

        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast(DEVICE.type):
          cnn_feats = cnn_enc(roll_batch)           # (N,T,64)
          logits = fusion_model(seq_batch, cnn_feats)      # (N,num_classes)
          loss = criterion(logits, y_batch)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(params, 1.0)
        scaler.step(optimizer)
        scaler.update()
        running += loss.item()

    # … your existing evaluate_model(val_loader) adapted to take (seq, roll, y) …
    val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate_fusion(cnn_enc, fusion_model, val_loader, DEVICE)
    print(f"Train Loss: {running/len(train_loader):.4f}, "
          f"Val Loss: {val_loss:.4f}, "
          f"Val Acc: {val_acc:.4f}, "
          f"Val Prec: {val_prec:.4f}, "
          f"Val Rec: {val_rec:.4f}, "
          f"Val F1: {val_f1:.4f}")

    # Log the results
    logger["epoch"].append(epoch+1)
    logger["train_loss"].append(running / max(1, len(train_loader)))
    logger["val_loss"].append(val_loss)
    logger["val_acc"].append(val_acc)
    logger["val_prec"].append(val_prec)
    logger["val_rec"].append(val_rec)
    logger["val_f1"].append(val_f1)

    print(f"Epoch {epoch+1:02d} | train_loss={logger['train_loss'][-1]:.4f} "
          f"| val_loss={val_loss:.4f} | acc={val_acc:.3f} | P={val_prec:.3f} | R={val_rec:.3f} | F1={val_f1:.3f}")

# Save the trained model
torch.save({
    'cnn_encoder_state_dict': cnn_enc.state_dict(),
    'fusion_model_state_dict': fusion_model.state_dict(),
}, 'composer_fusion_model.pth')
# Out:
# Epoch 1/30
# Train Loss: 0.7362, Val Loss: 0.6647, Val Acc: 0.7670, Val Prec: 0.2557, Val Rec: 0.3333, Val F1: 0.2894
# Epoch 01 | train_loss=0.7362 | val_loss=0.6647 | acc=0.767 | P=0.256 | R=0.333 | F1=0.289
# Epoch 2/30
# Train Loss: 0.5705, Val Loss: 0.5557, Val Acc: 0.7998, Val Prec: 0.5171, Val Rec: 0.4223, Val F1: 0.4325
# Epoch 02 | train_loss=0.5705 | val_loss=0.5557 | acc=0.800 | P=0.517 | R=0.422 | F1=0.432
# Epoch 3/30
# Train Loss: 0.4893, Val Loss: 0.5153, Val Acc: 0.8355, Val Prec: 0.5277, Val Rec: 0.5277, Val F1: 0.5256
# Epoch 03 | train_loss=0.4893 | val_loss=0.5153 | acc=0.836 | P=0.528 | R=0.528 | F1=0.526
# Epoch 4/30
# Train Loss: 0.4704, Val Loss: 0.4684, Val Acc: 0.8414, Val Prec: 0.5398, Val Rec: 0.5325, Val F1: 0.5333
# Epoch 04 | train_loss=0.4704 | val_loss=0.4684 | acc=0.841 | P=0.540 | R=0.533 | F1=0.533
# Epoch 5/30
# Train Loss: 0.3926, Val Loss: 0.4209, Val Acc: 0.8517, Val Prec: 0.6222, Val Rec: 0.5492, Val F1: 0.5532
# Epoch 05 | train_loss=0.3926 | val_loss=0.4209 | acc=0.852 | P=0.622 | R=0.549 | F1=0.553
# Epoch 6/30
# Train Loss: 0.2897, Val Loss: 0.3638, Val Acc: 0.8884, Val Prec: 0.8612, Val Rec: 0.7190, Val F1: 0.7736
# Epoch 06 | train_loss=0.2897 | val_loss=0.3638 | acc=0.888 | P=0.861 | R=0.719 | F1=0.774
# Epoch 7/30
# Train Loss: 0.3034, Val Loss: 0.3030, Val Acc: 0.9001, Val Prec: 0.8493, Val Rec: 0.7818, Val F1: 0.8116
# Epoch 07 | train_loss=0.3034 | val_loss=0.3030 | acc=0.900 | P=0.849 | R=0.782 | F1=0.812
# Epoch 8/30
# Train Loss: 0.2252, Val Loss: 0.2704, Val Acc: 0.9001, Val Prec: 0.8604, Val Rec: 0.7394, Val F1: 0.7856
# Epoch 08 | train_loss=0.2252 | val_loss=0.2704 | acc=0.900 | P=0.860 | R=0.739 | F1=0.786
# Epoch 9/30
# Train Loss: 0.2029, Val Loss: 0.2566, Val Acc: 0.9070, Val Prec: 0.8415, Val Rec: 0.8546, Val F1: 0.8398
# Epoch 09 | train_loss=0.2029 | val_loss=0.2566 | acc=0.907 | P=0.842 | R=0.855 | F1=0.840
# Epoch 10/30
# Train Loss: 0.1775, Val Loss: 0.2535, Val Acc: 0.9016, Val Prec: 0.7980, Val Rec: 0.8896, Val F1: 0.8356
# Epoch 10 | train_loss=0.1775 | val_loss=0.2535 | acc=0.902 | P=0.798 | R=0.890 | F1=0.836
# Epoch 11/30
# Train Loss: 0.1626, Val Loss: 0.2746, Val Acc: 0.9065, Val Prec: 0.8304, Val Rec: 0.8804, Val F1: 0.8526
# Epoch 11 | train_loss=0.1626 | val_loss=0.2746 | acc=0.907 | P=0.830 | R=0.880 | F1=0.853
# Epoch 12/30
# Train Loss: 0.1634, Val Loss: 0.2409, Val Acc: 0.9256, Val Prec: 0.9243, Val Rec: 0.7976, Val F1: 0.8462
# Epoch 12 | train_loss=0.1634 | val_loss=0.2409 | acc=0.926 | P=0.924 | R=0.798 | F1=0.846
# Epoch 13/30
# Train Loss: 0.1355, Val Loss: 0.2110, Val Acc: 0.9359, Val Prec: 0.9483, Val Rec: 0.8233, Val F1: 0.8749
# Epoch 13 | train_loss=0.1355 | val_loss=0.2110 | acc=0.936 | P=0.948 | R=0.823 | F1=0.875
# Epoch 14/30
# Train Loss: 0.1146, Val Loss: 0.1870, Val Acc: 0.9413, Val Prec: 0.9021, Val Rec: 0.9045, Val F1: 0.9024
# Epoch 14 | train_loss=0.1146 | val_loss=0.1870 | acc=0.941 | P=0.902 | R=0.905 | F1=0.902
# Epoch 15/30
# Train Loss: 0.0937, Val Loss: 0.1982, Val Acc: 0.9403, Val Prec: 0.9218, Val Rec: 0.8783, Val F1: 0.8980
# Epoch 15 | train_loss=0.0937 | val_loss=0.1982 | acc=0.940 | P=0.922 | R=0.878 | F1=0.898
# Epoch 16/30
# Train Loss: 0.1289, Val Loss: 0.2221, Val Acc: 0.9256, Val Prec: 0.8711, Val Rec: 0.8787, Val F1: 0.8744
# Epoch 16 | train_loss=0.1289 | val_loss=0.2221 | acc=0.926 | P=0.871 | R=0.879 | F1=0.874
# Epoch 17/30
# Train Loss: 0.1247, Val Loss: 0.1789, Val Acc: 0.9447, Val Prec: 0.9450, Val Rec: 0.8696, Val F1: 0.9038
# Epoch 17 | train_loss=0.1247 | val_loss=0.1789 | acc=0.945 | P=0.945 | R=0.870 | F1=0.904
# Epoch 18/30
# Train Loss: 0.0936, Val Loss: 0.1939, Val Acc: 0.9339, Val Prec: 0.8813, Val Rec: 0.8922, Val F1: 0.8848
# Epoch 18 | train_loss=0.0936 | val_loss=0.1939 | acc=0.934 | P=0.881 | R=0.892 | F1=0.885
# Epoch 19/30
# Train Loss: 0.0956, Val Loss: 0.1854, Val Acc: 0.9442, Val Prec: 0.9316, Val Rec: 0.8717, Val F1: 0.8993
# Epoch 19 | train_loss=0.0956 | val_loss=0.1854 | acc=0.944 | P=0.932 | R=0.872 | F1=0.899
# Epoch 20/30
# Train Loss: 0.0771, Val Loss: 0.1775, Val Acc: 0.9476, Val Prec: 0.9144, Val Rec: 0.9164, Val F1: 0.9154
# Epoch 20 | train_loss=0.0771 | val_loss=0.1775 | acc=0.948 | P=0.914 | R=0.916 | F1=0.915
# Epoch 21/30
# Train Loss: 0.0723, Val Loss: 0.1822, Val Acc: 0.9481, Val Prec: 0.9073, Val Rec: 0.9242, Val F1: 0.9147
# Epoch 21 | train_loss=0.0723 | val_loss=0.1822 | acc=0.948 | P=0.907 | R=0.924 | F1=0.915
# Epoch 22/30
# Train Loss: 0.0699, Val Loss: 0.1838, Val Acc: 0.9481, Val Prec: 0.9210, Val Rec: 0.8970, Val F1: 0.9073
# Epoch 22 | train_loss=0.0699 | val_loss=0.1838 | acc=0.948 | P=0.921 | R=0.897 | F1=0.907
# Epoch 23/30
# Train Loss: 0.0622, Val Loss: 0.1870, Val Acc: 0.9525, Val Prec: 0.9106, Val Rec: 0.9330, Val F1: 0.9202
# Epoch 23 | train_loss=0.0622 | val_loss=0.1870 | acc=0.953 | P=0.911 | R=0.933 | F1=0.920
# Epoch 24/30
# Train Loss: 0.0650, Val Loss: 0.2109, Val Acc: 0.9501, Val Prec: 0.9277, Val Rec: 0.9047, Val F1: 0.9140
# Epoch 24 | train_loss=0.0650 | val_loss=0.2109 | acc=0.950 | P=0.928 | R=0.905 | F1=0.914
# Epoch 25/30
# Train Loss: 0.0623, Val Loss: 0.2957, Val Acc: 0.9432, Val Prec: 0.9256, Val Rec: 0.8858, Val F1: 0.9015
# Epoch 25 | train_loss=0.0623 | val_loss=0.2957 | acc=0.943 | P=0.926 | R=0.886 | F1=0.901
# Epoch 26/30
# Train Loss: 0.0596, Val Loss: 0.2603, Val Acc: 0.9476, Val Prec: 0.8986, Val Rec: 0.9217, Val F1: 0.9077
# Epoch 26 | train_loss=0.0596 | val_loss=0.2603 | acc=0.948 | P=0.899 | R=0.922 | F1=0.908
# Epoch 27/30
# Train Loss: 0.0629, Val Loss: 0.2628, Val Acc: 0.9511, Val Prec: 0.9494, Val Rec: 0.8913, Val F1: 0.9178
# Epoch 27 | train_loss=0.0629 | val_loss=0.2628 | acc=0.951 | P=0.949 | R=0.891 | F1=0.918
# Epoch 28/30
# Train Loss: 0.0553, Val Loss: 0.2423, Val Acc: 0.9496, Val Prec: 0.9339, Val Rec: 0.8899, Val F1: 0.9107
# Epoch 28 | train_loss=0.0553 | val_loss=0.2423 | acc=0.950 | P=0.934 | R=0.890 | F1=0.911
# Epoch 29/30
# Train Loss: 0.0523, Val Loss: 0.2862, Val Acc: 0.9457, Val Prec: 0.9097, Val Rec: 0.9125, Val F1: 0.9100
# Epoch 29 | train_loss=0.0523 | val_loss=0.2862 | acc=0.946 | P=0.910 | R=0.912 | F1=0.910
# Epoch 30/30
# Train Loss: 0.0609, Val Loss: 0.2500, Val Acc: 0.9520, Val Prec: 0.9321, Val Rec: 0.9122, Val F1: 0.9206
# Epoch 30 | train_loss=0.0609 | val_loss=0.2500 | acc=0.952 | P=0.932 | R=0.912 | F1=0.921

# %% [markdown]
# Model Evaluation: Evaluate the performance of the deep learning model using accuracy, precision, and recall metrics.

# %%
# Plotting the training and validation metrics
epochs = logger["epoch"]

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(epochs, logger["train_loss"], marker='o', label='Train Loss')
plt.plot(epochs, logger["val_loss"],   marker='o', label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('Loss over Epochs'); plt.legend(); plt.grid(True, alpha=0.3)

# %%
plt.subplot(1,2,2)
plt.plot(epochs, logger["val_acc"],  marker='o', label='Val Acc')
plt.plot(epochs, logger["val_prec"], marker='o', label='Val Precision (macro)')
plt.plot(epochs, logger["val_rec"],  marker='o', label='Val Recall (macro)')
plt.plot(epochs, logger["val_f1"],   marker='o', label='Val F1 (macro)')
plt.xlabel('Epoch'); plt.ylabel('Score'); plt.title('Validation Metrics'); plt.legend(); plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Model Optimization: Optimize the deep learning model by fine-tuning hyperparameters.
